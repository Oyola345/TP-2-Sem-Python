# %%
import sys
sys.path.append('../src')

# %%
import ejercicio_10
# Out:
# Ronda 1 - Entrada:
#   *Ganador: Camila (26 puntos)
#   Puesto 2: Valentina (24 puntos)
#   Puesto 3: Lucía (24 puntos)
#   Puesto 4: Mateo (22 puntos)
#   Puesto 5: Santiago (19 puntos)
#
# Ronda 2 - Plato principal:
#   *Ganador: Valentina (26 puntos)
#   Puesto 2: Santiago (25 puntos)
#   Puesto 3: Mateo (24 puntos)
#   Puesto 4: Lucía (22 puntos)
#   Puesto 5: Camila (20 puntos)
#
# Ronda 3 - Postre:
#   *Ganador: Lucía (27 puntos)
#   Puesto 2: Mateo (26 puntos)
#   Puesto 3: Camila (24 puntos)
#   Puesto 4: Valentina (22 puntos)
#   Puesto 5: Santiago (20 puntos)
#
# Ronda 4 - Cocina internacional:
#   *Ganador: Valentina (26 puntos)
#   Puesto 2: Camila (25 puntos)
#   Puesto 3: Santiago (24 puntos)
#   Puesto 4: Lucía (22 puntos)
#   Puesto 5: Mateo (20 puntos)
#
# Ronda 5 - Final libre:
#   *Ganador: Santiago (27 puntos)
#   Puesto 2: Valentina (26 puntos)
#   Puesto 3: Mateo (25 puntos)
#   Puesto 4: Lucía (23 puntos)
#   Puesto 5: Camila (21 puntos)
#
# ...
