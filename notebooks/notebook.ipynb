# %%
import sys
sys.path.append('../src')

# %%
import ejercicio_1

# %%
import ejercicio_2

# %%
import ejercicio_3
# Out:
# La película sigue a un grupo de astronautas que viajan a ***** en una misión de rescate. El capitán ****** lidera al equipo a través de tormentas solares y fallos en el sistema de navegación. Al llegar a ***** descubren que la base está abandonada y los suministros destruidos. ****** decide ********** la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia. El final revela que ****** sobrevivió gracias a un pasaje secreto.
